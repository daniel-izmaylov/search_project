# %%
import itertools
from collections import defaultdict
import random
import numpy as np
from multiprocessing import Pool
pool=Pool(64)

def h(state):
    return sum(abs(state[i]-state[i-1])>1 for i in range(1,len(state)))


def permutation_and_h(n,n_limit=100):
    h_dict=defaultdict(int)
    init_list= list(range(1,n+1))
    # res_list= list(map(lambda x: sum(abs(x[i]-x[i-1])>1 for i in range(1,len(x))), [list(x)for x in itertools.permutations(init_list)]))
    # per_list= list(itertools.islice(itertools.permutations(init_list), 3,8))
    per_list=[ np.random.permutation(init_list) for i in range(n_limit)]
    res_list= list(pool.map(h, per_list))
    for i in res_list:
        h_dict[i]+=1

    total_h= sum(h_dict.values())        
    for i in range(0,n+1):
        if i >=1:
            h_dict[i]+=h_dict[i-1]
    for i in range(0,n+1):
        h_dict[i]=h_dict[i]/total_h
    return h_dict



def calcalute_KRE(d,problem_size):
    p=all_dict_h[problem_size]
    b=problem_size-1
    sum_res=0
    for i in range(0,d+1):
        sum_res+=b**i*p[d-i]
    return sum_res



n_limit=3628800
t=permutation_and_h(10,3628800)
t
# Out:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-37:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-44:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-45:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-43:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/izmaylov/.conda/envs/tf_cpu/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_104035/1639705890.py in <module>
#      41
#      42 n_limit=3628800
# ---> 43 t=permutation_and_h(10,3628800)
#      44 t
#
# /tmp/ipykernel_104035/1639705890.py in permutation_and_h(n, n_limit)
#      15     # res_list= list(map(lambda x: sum(abs(x[i]-x[i-1])>1 for i in range(1,len(x))), [list(x)for x in itertools.permutations(init_list)]))
#      16     # per_list= list(itertools.islice(itertools.permutations(init_list), 3,8))
# ---> 17     per_list=[ np.random.permutation(init_list) for i in range(n_limit)]
#      18     res_list= list(pool.map(h, per_list))
#      19     for i in res_list:
#
# /tmp/ipykernel_104035/1639705890.py in <listcomp>(.0)
#      15     # res_list= list(map(lambda x: sum(abs(x[i]-x[i-1])>1 for i in range(1,len(x))), [list(x)for x in itertools.permutations(init_list)]))
#      16     # per_list= list(itertools.islice(itertools.permutations(init_list), 3,8))
# ---> 17     per_list=[ np.random.permutation(init_list) for i in range(n_limit)]
#      18     res_list= list(pool.map(h, per_list))
#      19     for i in res_list:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.permutation()
#
# <__array_function__ internals> in may_share_memory(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
#check number of cores in your machine
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 128

# %%
from pandarallel import pandarallel
# pandarallel.initialize(progress_bar=True)
# from multiprocesspandas import applyparallel

import pandas as pd 
#read csv 
df_res = pd.read_csv('pancake_results.csv')


def helper(x):
    return calcalute_KRE(x["optimal_cost"],x["problem_size"])
all_dict_h={}
for problem_size in df_res.problem_size.unique():
    # all_dict_h[problem_size]=permutation_and_h(problem_size)
    all_dict_h[problem_size]=t
# df_res["pred_KRE"]= df_res.progress_apply(helper,axis=1,num_processes=8)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
df_res["pred_KRE"]= df_res.progress_apply(helper,axis=1)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df_res.sort_values(by=['optimal_cost'],inplace=True)
df_res
# Out:
#                               start  problem_size  bound  optimal_cost  cost  \
# 29  (9, 5, 4, 3, 8, 6, 7, 2, 1, 10)            10      0             5     5
# 32  (1, 7, 4, 3, 2, 9, 8, 5, 6, 10)            10      0             6     6
# 44  (5, 9, 6, 7, 8, 10, 3, 4, 2, 1)            10      0             7     7
# 18  (7, 8, 5, 9, 1, 10, 3, 2, 6, 4)            10      0             9     9
# 6   (1, 7, 5, 8, 4, 3, 9, 6, 2, 10)            10      0             9     9
# 30  (1, 5, 10, 3, 6, 2, 7, 8, 4, 9)            10      0             9     9
# 0   (4, 1, 10, 7, 3, 9, 5, 2, 6, 8)            10      0            10    10
# 48  (8, 5, 10, 3, 1, 4, 6, 2, 7, 9)            10      0            10    10
# 37  (3, 2, 5, 9, 7, 1, 10, 8, 4, 6)            10      0            10    10
# 49  (1, 5, 10, 9, 4, 8, 3, 6, 2, 7)            10      0            10    10
# 34  (2, 8, 1, 3, 10, 6, 4, 9, 7, 5)            10      0            11    11
#
#     states generated algorithm       pred_KRE
# 29                19      IDA*       0.699547
# 32                73      IDA*       6.557963
# 44               525      IDA*      59.589330
# 41               298      IDA*      59.589330
# 38              1808      IDA*      59.589330
# 45                52      IDA*      59.589330
# 35                42      IDA*      59.589330
# 27              2788      IDA*      59.589330
# 26               223      IDA*      59.589330
# 25               286      IDA*      59.589330
# 40               437      IDA*     537.171839
# 28               123      IDA*     537.171839
# 21              1839      IDA*     537.171839
# 20               696      IDA*     537.171839
# 19               931      IDA*     537.171839
# 16              2039      IDA*     537.171839
# 24               881      IDA*     537.171839
# 22               465      IDA*     537.171839
# 14              1511      IDA*     537.171839
# 1                682      IDA*     537.171839
# 12               448      IDA*     537.171839
# 2               3456      IDA*     537.171839
# 11                70      IDA*     537.171839
# 8                864      IDA*     537.171839
# 42              7967      IDA*    4835.546550
# 39              4482      IDA*    4835.546550
# 3              14670      IDA*    4835.546550
# 4                131      IDA*    4835.546550
# 36              1117      IDA*    4835.546550
# 5               2260      IDA*    4835.546550
# 46               653      IDA*    4835.546550
# 33              3421      IDA*    4835.546550
# 17              1055      IDA*    4835.546550
# 31              7823      IDA*    4835.546550
# 15              1504      IDA*    4835.546550
# 7               2241      IDA*    4835.546550
# 9               2759      IDA*    4835.546550
# 10              1470      IDA*    4835.546550
# 47              3039      IDA*    4835.546550
# 23               512      IDA*    4835.546550
# 43               189      IDA*    4835.546550
# 13              1154      IDA*    4835.546550
# 18              6220      IDA*    4835.546550
# 6                188      IDA*    4835.546550
# 30              1471      IDA*    4835.546550
# 0               5462      IDA*   43520.918951
# 48              3891      IDA*   43520.918951
# 37              4503      IDA*   43520.918951
# 49              5336      IDA*   43520.918951
# 34              9642      IDA*  391688.270558

# %%
from flip_pancake import pancake_neighbours
import ast
from slide_tile import slide_neighbours

def cacalute_per_state_h(state):
    lst=[]
    h_state=h(state)
    for neighbor in pancake_neighbours(list(state)):
        neighbor=neighbor[1]
        h_neighbor= h(neighbor)
        lst.append(h_neighbor)
    return h_state,lst
        

def condisinal_h(n,n_limit=100):
    dict_h={}
    init_list= list(range(1,n+1))
    for i in range (n):
        dict_h[i]=defaultdict(int)
    per_list=[ list(np.random.permutation(init_list)) for i in range(n_limit)]
    res_lst= list(pool.map(cacalute_per_state_h,per_list))
    for father_h, neighbours_h_lst in res_lst:
        for h_neighbor in neighbours_h_lst:
            dict_h[father_h][h_neighbor]+=1
       
    for key in dict_h.keys():
        total=sum(dict_h[key].values())
        for key2 in dict_h[key].keys():
            dict_h[key][key2]=dict_h[key][key2]/total
    return dict_h

all_dict_condisonal_h={}
for problem_size in df_res.problem_size.unique():
    all_dict_condisonal_h[problem_size]=condisinal_h(problem_size,n_limit=n_limit)

# %%
all_dict_condisonal_h[problem_size]
# Out:
# {0: defaultdict(int, {1: 0.8888888888888888, 0: 0.1111111111111111}),
#  1: defaultdict(int,
#              {2: 0.7533875338753387,
#               0: 0.032520325203252036,
#               1: 0.2140921409214092}),
#  2: defaultdict(int,
#              {3: 0.6367980884109916,
#               2: 0.31645758661887696,
#               1: 0.04674432497013142}),
#  3: defaultdict(int,
#              {3: 0.4044939029589835,
#               4: 0.5353031465848043,
#               2: 0.06020295045621216}),
#  4: defaultdict(int,
#              {4: 0.48408026293872214,
#               5: 0.438236620473631,
#               3: 0.07768311658764691}),
#  5: defaultdict(int,
#              {5: 0.5513096942642971,
#               6: 0.34812085310274477,
#               4: 0.10056945263295806}),
#  6: defaultdict(int,
#              {6: 0.6113755789337947,
#               7: 0.2617651508677632,
#               5: 0.12685927019844212}),
#  7: defaultdict(int,
#              {8: 0.1759900797703597,
#               6: 0.15368291939793333,
#               7: 0.6703270008317069}),
#  8: defaultdict(int,
#              {8: 0.7322278348471107,
#               9: 0.08892844744396168,
#               7: 0.17884371770892754}),
#  9: defaultdict(int, {9: 0.7977535106599999, 8: 0.20224648934000009})}

# %%
# pandarallel.initialize(progress_bar=True)
from multiprocesspandas import applyparallel


def calcalute_CDP(s,d):
    sum_res=0
    for i in range (0,d+1):
        for v in range (0,d-i+1):
            sum_res+=calcalute_CDP_helper(i,s,v,d)
    return sum_res


def calcalute_CDP_helper(i,s,v,d):
    state_h=h(s)
    b=len(s)-1
    problem_size=len(s)
    local_dict=all_dict_condisonal_h[problem_size]
    
    if i==0 and v==state_h:
        return 1 
    if i==0 and v!=state_h:
        return 0
    else:
        sum_res=0
        for v_p in range (0,d-(i-1)+1):
            try:
                if state_h not in local_dict:
                    p=0
                else:
                    p=local_dict[state_h][v_p]
            except keyError:
                p=0
            sum_res+=calcalute_CDP_helper(i-1,s,v_p,d)*b*p #Todo: check the order of the dict
    return sum_res

calcalute_CDP(ast.literal_eval(df_res.iloc[0]["start"]),df_res.iloc[0]["optimal_cost"])
        # for neighbor in pancake_neighbours(s):
        #     neighbor=neighbor[1]
        #     sum_res+=calcalute_CDP_helper(i-1,neighbor,v)
        # return sum_res


def helper_cdp(x):
    return calcalute_CDP(ast.literal_eval(x["start"]),x["optimal_cost"])

# df_res["pred_CDP"]= df_res.apply(lambda x: calcalute_CDP(ast.literal_eval(x["start"]),x["optimal_cost"]),axis=1)
# df.
# df_res["pred_CDP"]= df_res.parallel_apply(func)(helper_cdp,axis=1)
df_res["pred_CDP"]= df_res.parallel_apply(helper_cdp,axis=1)
# df_res["pred_CDP"]= df_res.apply_parallel(helper_cdp,num_processes=8)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df_res.to_csv("res_cdp_10.csv",index=False)

# %%
df_res["dist_kre"]=abs(df_res["states generated"]-df_res["pred_KRE"])
df_res["dist_cdp"]=abs(df_res["states generated"]-df_res["pred_CDP"])

# %%
df_res["dist_kre"].std()
# Out:
# 54308.40013384217

# %%
df_res["states generated"].mean()
# Out:
# 2274.32

# %%
df_res["dist_kre"].mean(),df_res["dist_cdp"].mean()
# Out:
# (12474.434986590608, 3340.5847502074553)

# %%
df_res["dist_kre"].std(),df_res["dist_cdp"].std()
# Out:
# (54308.40013384217, 6701.708278707517)
